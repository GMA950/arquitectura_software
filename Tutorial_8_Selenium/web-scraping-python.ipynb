# %% [markdown]
# # Scraping de datos e Integración MySQL/Python

# %%
# !python -V
# Out:
# Python 3.7.6

# %%
# !pip -V
# Out:
# pip 20.1.1 from /home/gma950/.local/lib/python3.7/site-packages/pip (python 3.7)

# %% [markdown]
# ## 1. Realizar consultas HTTP en Python: _Requests_
#
# [_Requests_](https://2.python-requests.org//es/latest/) es una librería Python que facilita el envio de consultas HTTP/1.1.

# %%
# !pip install requests

# %%
import requests

# %%
URL = "https://www.latercera.com/"

r = requests.get(URL)

# %%
print(r.headers)
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Server': 'openresty', 'ETag': 'W/"1d6bc9-eYfCAgRvah26SVKwkd1abwC0PtI"', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,2', 'Cache-Control': 'max-age=60', 'Expires': 'Tue, 16 Jun 2020 20:13:06 GMT', 'Date': 'Tue, 16 Jun 2020 20:12:06 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Server-Timing': 'cdn-cache; desc=HIT, edge; dur=1', 'Content-Security-Policy': 'upgrade-insecure-requests'}

# %%
print(r.headers['Content-Type'])
print(r.encoding)
# Out:
# text/html; charset=utf-8
# utf-8

# %%
print(r.text)
# Out:
# <!DOCTYPE html><html><head><title>La Tercera</title><meta http-equiv="refresh" content="300"/><script>var digitalData={"chartbeat_uid":"14295","chartbeat_domain":"latercera.com","siteDomainURL":"https://www.latercera.com","section":"Portada","tag":"","author":"","pageInstanceID":"home","page":{"pageInfo":{"pageID":"home","storyTitle":"","pageName":"home","destinationURL":"https://www.latercera.com","author":"","issueDate":"","effectiveDate":"","publisher":"latercera.com","tags":[""]},"category":{"primaryCategory":"home","subCategory1":"home","pageType":"home"},"attributes":{"country":"CL","language":"es-cl","server":"latercera_prod"}}}</script><script>/* Google Tag Manager */
#             if (window) {
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# ...

# %% [markdown]
# Tutorial para uso más avanzado de _Requests_:
# - _Requests_ quickstart [[1]](https://2.python-requests.org//es/latest/user/quickstart.html)
# - uso avanzado de _Requests_ [[2]](https://2.python-requests.org//es/latest/user/advanced.html)

# %% [markdown]
# ## 2. Extraer datos de documentos HTML en Python: _BeautifulSoup4_

# %% [markdown]
# [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) es una librería Python que facilita la extracción de datos en archivos HTML y XML.

# %%
# !pip install beautifulsoup4

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

bs = BeautifulSoup(html_doc, 'html5lib')

# %%
a_tags = bs.find_all('a')

for a_tag in a_tags:
    print(a_tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for a_tag in a_tags:
    print(a_tag.text)
# Out:
# Elsie
# Lacie
# Tillie

# %%
for a_tag in a_tags:
    print(a_tag['href'])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
p_tags = bs.find_all('p',attrs = {'class':'title'})
for p_tag in p_tags:
    print(p_tag.text)
# Out:
# The Dormouse's story

# %% [markdown]
# ## 3. Extraer enlaces de noticias desde un medio de prensa: _Requests_ y _BeautifulSoup4_
#
# **Nota Bene**: Multiplicar de forma automática las consultas HTTP hacia un sitio web es una mala práctica que no respeta las condiciones de uso del sitio. En ciertos paises, está prohibido por leyes.
# Para evitar abusar las condiciones de uso de los sitios, cuidaremos no enviar más de 2 consultas por minuto hacia el mismo sitio.
#
# Para evitar abusos, cada grupo de estudiantes utilizaran sitios de medios de prensa distintos:
# - La Tercera: https://www.latercera.com/
# - Cooperativa: https://www.cooperativa.cl/
# - Bio Bio: https://www.biobiochile.cl/
# - CNN Chile: https://www.cnnchile.com/
# - 24 Horas TVN: https://www.24horas.cl/
# - El País (España): https://elpais.com/elpais/portada_america.html
# - El Mundo (españa): https://www.elmundo.es/
# -

# %%
URL = "https://www.elmundo.es/ultimas-noticias.html"

r = requests.get(URL)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-15"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge;chrome=1"/>
# <title data-ue-u="title" data-ue-c="innerHTML">Últimas noticias - Noticias de última hora | EL MUNDO</title>
# <link rel="stylesheet" href="https://e00-elmundo.uecdn.es/assets/desktop/master/css/lomasleido/style.css" type="text/css" media="all"/>
# <meta name="viewport" content="width=device-width, minimum-scale=1.0, initial-scale=1.0"> <link rel="preload" href="https://e00.uecdn.es/fonts/valencia/valencia-bold-webfont.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="https://e00.uecdn.es/fonts/valencia/valencia-regular-webfont.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="https://e00.uecdn.es/fonts/valencia/valencia-bolditalic-webfont.woff2" as="font" type="font/woff2" crossorigin>
# ...

# %%
bs = BeautifulSoup(r.text, 'html5lib')

a_tags = bs.find_all('a')

for a_tag in a_tags:
    print(a_tag['href'])
# Out:
# https://www.elmundo.es/ciencia-y-salud/salud/2020/06/16/5ee85e5efc6c837a438b4576.html
# https://www.elmundo.es/ciencia-y-salud/salud/2020/06/16/5ee8dd9bfdddff078b8b45e2.html
# https://www.elmundo.es/economia/2020/06/15/5ee36da2fc6c83f7018b4750.html
# https://www.elmundo.es/economia/2020/06/15/5ee35ef9fc6c831f6f8b46df.html
# https://www.elmundo.es/economia/2020/06/16/5ee86aa121efa0077f8b4584.html
# https://www.elmundo.es/internacional/2020/06/16/5ee8a92cfc6c83a9358b463a.html
# https://www.elmundo.es/internacional/2020/06/15/5ee77944fc6c83a9358b45cb.html
# https://www.elmundo.es/television/momentvs/2020/06/16/5ee8677321efa0077f8b4574.html?
# https://www.elmundo.es/tecnologia/2020/06/15/5ee78da621efa0156e8b467e.html
# https://www.elmundo.es/motor/2020/06/16/5ee86f1dfdddff34458b4627.html
# https://www.elmundo.es/motor/2020/06/15/5ee76f0721efa0f3268b4661.html
# https://www.elmundo.es?intcmp=MENUHOM02&s_kw=portada
# https://www.elmundo.es?intcmp=MENUMIGA01&s_kw=portada
# ...

# %%
a_tags = bs.find_all('a', attrs={"class":"ue-c-cover-content__link"})

enlaces=[]

for a_tag in a_tags:
    h2_tags = a_tag.find_all('h2')
    for h2_tag in h2_tags:
        print(h2_tag.text)
        
    print(a_tag['href'])
    enlaces.append(a_tag['href'])
# Out:
# Merluza en salsa de almendras
# https://www.elmundo.es/vida-sana/estilo-y-gastro/2020/06/16/5ee926e3fc6c835a368b45ca.html
# Huidos, refuerzos y recuperados: así llegan los 12 equipos a la fase final de la ACB
# https://www.elmundo.es/deportes/baloncesto/liga-endesa/2020/06/16/5ee913cffc6c83192e8b45ee.html
# Luces y sombras del insólito retorno de la Liga ACB
# https://www.elmundo.es/deportes/baloncesto/liga-endesa/2020/06/16/5ee90966fc6c83893f8b462f.html
# Así será la reapertura de piscinas municipales en Madrid el 1 de julio: aforo del 30%, turnos con reserva y prohibido comer
# https://www.elmundo.es/madrid/2020/06/16/5ee8afeefdddff54198b459b.html
# Carlos Sainz, sin fecha de caducidad: "Si le dan un coche competitivo, seguirá dando guerra en el Dakar"
# https://www.elmundo.es/deportes/mas-motor/2020/06/16/5ee9144921efa0f4298b45b9.html
# El Villarreal sufre para tumbar al Mallorca
# https://www.elmundo.es/deportes/futbol/2020/06/16/5ee9226bfc6c83013b8b4642.html
# ...

# %% [markdown]
# ## 4. Extraer contenidos de noticias

# %%
import time

noticias=[]

for enlace in enlaces:
    
    time.sleep(2)
    print(enlace)
    r = requests.get(enlace)

    bs = BeautifulSoup(r.text, 'html5lib')

    div_noticia = bs.find('div', attrs={'class':'ue-l-article__body ue-c-article__body'})
    
    texto_noticia=""
    
    try:
        p_tags = div_noticia.find_all('p')

        for p_tag in p_tags:
            texto_noticia = texto_noticia+p_tag.text
            
    except:
        continue
        
    noticias.append((enlace,texto_noticia))
# Out:
# https://www.elmundo.es/vida-sana/estilo-y-gastro/2020/06/16/5ee926e3fc6c835a368b45ca.html
# https://www.elmundo.es/deportes/baloncesto/liga-endesa/2020/06/16/5ee913cffc6c83192e8b45ee.html
# https://www.elmundo.es/deportes/baloncesto/liga-endesa/2020/06/16/5ee90966fc6c83893f8b462f.html
# https://www.elmundo.es/madrid/2020/06/16/5ee8afeefdddff54198b459b.html
# https://www.elmundo.es/deportes/mas-motor/2020/06/16/5ee9144921efa0f4298b45b9.html
# https://www.elmundo.es/deportes/futbol/2020/06/16/5ee9226bfc6c83013b8b4642.html
# https://www.elmundo.es/deportes/baloncesto/liga-endesa/2020/06/16/5ee9057dfc6c83013b8b4627.html
# https://www.elmundo.es/ciencia-y-salud/salud/2020/06/16/5ee85e5efc6c837a438b4576.html
# https://www.elmundo.es/deportes/futbol/primera-division/2020/06/16/5ee91e5321efa0230c8b45f8.html
# https://www.elmundo.es/internacional/2020/06/16/5ee915d1fdddff408f8b45ca.html
# https://www.elmundo.es/loc/famosos/2020/06/16/5ee91a0afdddff1a478b45f5.html
# ...

# %%
noticias[7]
# Out:
# ('https://www.elmundo.es/internacional/2020/06/16/5ee915d1fdddff408f8b45ca.html',
# ...

# %% [markdown]
# ## 5. Aplicar procesos de Tratamiento Automático del Lenguaje

# %% [markdown]
# [SpaCy](https://spacy.io) es una librería Python que permite facilitar la realización de ciertos procesos de Tratamiento Automático del Lenguaje (TAL). Ejemplos de procesos de TAL son por ejemplos:
# - la tokenización: segmentar el texto en palabras,
# - la clasificación gramatical (pos): identificar si una palabra es un sustantivo, verbo, adjetivo, etc.
# - la lematización: determinar la forma genérica de una palabra (por ej.: "superó" --> "superar", "ocasiones" --> "ocasión")

# %%
# !pip install -U spacy
# Out:
# Requirement already up-to-date: spacy in /home/gma950/anaconda3/lib/python3.7/site-packages (2.3.0)
# ...

# %%
# !python -m spacy download es_core_news_sm
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')

# %%
# !python -m spacy download es_core_news_md
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_md')

# %%
import spacy
nlp = spacy.load('es_core_news_md')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-48-47cc7fa5ce1a> in <module>
#       1 import spacy
# ----> 2 nlp = spacy.load('es_core_news_md')
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         warnings.warn(Warnings.W001.format(path=depr_path), DeprecationWarning)
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     173     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     174         return load_model_from_path(name, **overrides)
# --> 175     raise IOError(Errors.E050.format(name=name))
#     176
#     177
#
# ...

# %%
doc=nlp(noticias[1][1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8403470497dd> in <module>
# ----> 1 doc=nlp(noticias[1][1])
#
# NameError: name 'nlp' is not defined

# %%
for token in doc:
    print(token.text, token.pos_)

# %%
for token in doc:
    if (token.pos_ == "NOUN"):
        print(token.text, token.pos_)

# %% [markdown]
# ## 6. Almacenar los resultados en una base de datos: _MySQL_

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

db_connection = mysql.connector.connect(user="root",host="localhost",password="1492sole+@LUCKY")
cursor = db_connection.cursor()

# %%
##EJECUTAR 1 VEZ
#cursor.execute("CREATE DATABASE info133_2020;")
cursor.execute("USE info133_2020")
#cursor.execute("CREATE TABLE news (idNews INT PRIMARY KEY NOT NULL AUTO_INCREMENT, url VARCHAR(200), text TEXT);")

# %%
for noticia in noticias:
    query="INSERT INTO news(url,text) VALUES (%s,%s)"
    cursor.execute(query,noticia)

cursor.execute("COMMIT");

# %% [markdown]
# ## 7. Ejercicio
#
# Lista de medios: https://docs.google.com/spreadsheets/d/1OrE-3TR0k8SSiu3rvrs6LwmsACM45MFIxtSS4UzO7ws/edit?usp=sharing
#
# Construir una base de datos con el modelo relacional siguiente (ver abajo) y escribir un script python para insertar datos automáticamente desde el archivo 'lista de medios' y técnicas de scraping de datos.
#
# MEDIA (PK_url_media, name, country, n_followers_facebook, n_followers_twitter, created_in, ideology, creator)
#
# NEWS (PK_url_news, title, text, publicated_in, #url_media)
#
# **NOTA BENE**: podrán completar la tabla NEWS con una lista reducida de medios (por ejemplo 2 medios).

# %%
#...FORMA 1
import csv
from collections import defaultdict

medios = []
with open('Lista_Medios - Feuille 1.csv') as File:
    reader = csv.reader(File, delimiter=',', quotechar=',',
                        quoting=csv.QUOTE_MINIMAL)
    for row in reader:
        medios.append(row)
        #print(row)
    print(medios)
# Out:
# [['Medio', 'URL WEB', 'País', 'N Seguidores FBK', 'URL Facebook', 'N°Seguidores en TTR', 'URL Twitter', 'Fecha de creación', 'Orientación Politica Aprox', 'Dueño'], ['Aristegui Noticias', 'https://aristeguinoticias.com', 'México', '7\u202f535\u202f309', 'https://www.facebook.com/AristeguiOnline', '8.5M', 'https://twitter.com/aristeguionline', '2012', 'Grupo de Periodistas Independientes', 'Carmen Aristegui'], ['El Financiero', 'https://www.elfinanciero.com.mx', 'México', '2\u202f087\u202f891', 'https://www.facebook.com/ElFinancieroMx', '1.3M', 'https://twitter.com/ElFinanciero_Mx', '15 de octubre de 1981', 'Derecha', 'by Grupo Multimedia Lauman'], ['El Universal', 'https://www.eluniversal.com.mx', 'México', '5\u202f231\u202f647', 'https://www.facebook.com/ElUniversalOnline', '5.5M', 'https://twitter.com/El_Universal_Mx', '1 de octubre de 1916 ', 'Derecha', 'EL UNIVERSAL C.P.N.'], ['El Economista', 'https://www.eleconomista.com.mx', 'México', '1\u202f122\u202f545', 'https://www.facebo
# ...

# %%
import pandas as pd
my_csv = pd.read_csv('Lista_Medios - Feuille 1.csv')
#column = my_csv.column_name
mediosdf = pd.read_csv('Lista_Medios - Feuille 1.csv', usecols=['Medio','URL WEB','País','N Seguidores FBK','N°Seguidores en TTR','Fecha de creación','Orientación Politica Aprox','Dueño'])
#print(medios_paradb['URL WEB'])
#print(medios_paradb)
lista_medios= mediosdf.values.tolist()
print(lista_medios)
# Out:
# [['Aristegui Noticias', 'https://aristeguinoticias.com', 'México', '7\u202f535\u202f309', '8.5M', '2012', 'Grupo de Periodistas Independientes', 'Carmen Aristegui'], ['El Financiero', 'https://www.elfinanciero.com.mx', 'México', '2\u202f087\u202f891', '1.3M', '15 de octubre de 1981', 'Derecha', 'by Grupo Multimedia Lauman'], ['El Universal', 'https://www.eluniversal.com.mx', 'México', '5\u202f231\u202f647', '5.5M', '1 de octubre de 1916 ', 'Derecha', 'EL UNIVERSAL C.P.N.'], ['El Economista', 'https://www.eleconomista.com.mx', 'México', '1\u202f122\u202f545', '593.7K ', 'December 5, 1988', 'Finanzas y Mercados = Liberal ', 'Nacer Global, empresa que agrupa tecnológicas + construcción + comunicación+ educación'], ['Wall Street Journal', 'https://www.wsj.com', 'USA', '6\u202f501\u202f954', '17.6M', 'July 8, 1889; 130 years ago', 'conservative', 'by Rupert Murdoch'], ['Washington Post', 'https://www.washingtonpost.com/?gclid=CjwKCAjwqJ_1BRBZEiwAv73uwBDit2oyWp7R0RoZ7YSEVLDV5FCJXeHxBSlqpjx
# ...

# %%
#SOLO UNA VEZ
#ursor.execute("CREATE DATABASE tarea_miercoles_info133;")
cursor.execute("USE tarea_miercoles_info133")
#cursor.execute("CREATE TABLE media(idMedia INT PRIMARY KEY NOT NULL AUTO_INCREMENT, PK_url_media VARCHAR(200), name VARCHAR(200), country VARCHAR(50), n_followers_facebook INT, n_followers_twitter INT, created_in VARCHAR(50), ideology VARCHAR(200), creator VARCHAR(200));")

# %%
for medio in lista_medios:
    print(medio)
    query="INSERT INTO media(PK_url_media,name,country,n_followers_facebook,n_followers_twitter,created_in,ideology,creator) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
    cursor.execute(query,medio)

cursor.execute("COMMIT");
# Out:
# ['Aristegui Noticias', 'https://aristeguinoticias.com', 'México', '7\u202f535\u202f309', '8.5M', '2012', 'Grupo de Periodistas Independientes', 'Carmen Aristegui']
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Data truncated for column 'n_followers_facebook' at row 1
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-41-188477a9903f> in <module>
#       2     print(medio)
# ...
